-- %%
DELETE FROM revr_bmbs_dmp_offline.dmp_offline_dcff_tags_with_info
WHERE tag_id IN (
    SELECT tag_id 
    FROM revr_bmbs_dmp_offline.dmp_tags_delete_from_segment_api
);

-- %%
DELETE FROM revr_bmbs_dmp_offline.dmp_offline_tags_with_info
WHERE tag_id IN (
    SELECT tag_id 
    FROM revr_bmbs_dmp_offline.dmp_tags_delete_from_segment_api
);
